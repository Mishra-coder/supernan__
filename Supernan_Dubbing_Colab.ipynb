# %% [markdown]
# # Supernan AI Automation Intern: Hindi Dubbing Pipeline
#
# **Author:**
#
# **Challenge:** The Golden 15 Seconds
#
# This notebook contains the environment setup for the advanced dubbing pipeline utilizing Demucs, WhisperX, Llama 3 (Groq), Coqui XTTS v2, and VideoReTalking.
#
# **Before running:** Go to `Runtime > Change runtime type` and select `T4 GPU`.

# %%
# !git clone https://github.com/Mishra-coder/supernan__.git
# %cd supernan__

# %%
# Install core system dependencies
# !sudo apt-get install ffmpeg

# Install Python dependencies
# !pip install -r requirements.txt

# Note: WhisperX and Coqui TTS often require specific exact versions of torch.
# !pip install TTS
# !pip install git+https://github.com/m-bain/whisperx.git

# %%
# VideoReTalking needs a separate environment setup due to old dependencies.
# !git clone https://github.com/OpenTalker/video-retalking.git
# %cd video-retalking
# !pip install -r requirements.txt
# !mkdir -p checkpoints
# Downloading the weights...
# !wget https://github.com/ajay-s-n/VideoReTalking/releases/download/v1.0/38d_10000_model.pth -O checkpoints/38d_10000_model.pth
# !wget https://github.com/ajay-s-n/VideoReTalking/releases/download/v1.0/D_Latest.pth -O checkpoints/D_Latest.pth
# !wget https://github.com/ajay-s-n/VideoReTalking/releases/download/v1.0/ENR_ckpt.pth -O checkpoints/ENR_ckpt.pth
# !wget https://github.com/ajay-s-n/VideoReTalking/releases/download/v1.0/GFPGANv1.3.pth -O checkpoints/GFPGANv1.3.pth
# !wget https://github.com/ajay-s-n/VideoReTalking/releases/download/v1.0/GPEN-BFR-512.pth -O checkpoints/GPEN-BFR-512.pth
# !wget https://github.com/ajay-s-n/VideoReTalking/releases/download/v1.0/ParseNet-latest.pth -O checkpoints/ParseNet-latest.pth
# !wget https://github.com/ajay-s-n/VideoReTalking/releases/download/v1.0/RetinaFace-R50.pth -O checkpoints/RetinaFace-R50.pth
# !wget https://github.com/ajay-s-n/VideoReTalking/releases/download/v1.0/shape_predictor_68_face_landmarks.dat -O checkpoints/shape_predictor_68_face_landmarks.dat
# %cd ..

# %%
# Ensure you upload the 'supernan_training.mp4' into supernan__/data/input/ first!
import os
os.environ['GROQ_API_KEY'] = 'your_groq_api_key_here'

# !python dub_video.py --config config.yaml
